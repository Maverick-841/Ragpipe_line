# %% [markdown]
# from langchain_core.documents import Document as DOC

# %%
from langchain_core.documents import Document as DOC

doc = DOC(
    page_content="Hello",
    metadata={"source": "test"}
)
print(doc)
# Out:
# page_content='Hello' metadata={'source': 'test'}

# %%
import os 
os.makedirs("../data/text_files", exist_ok=True)

# %%
sample_texts = {
    "../data/text_files/python_intro.txt": """Python Programming Introduction

Python is a high-level programming language.
It is easy to learn and widely used.
""",

    "../data/text_files/ml_intro.txt": """Machine Learning Basics

Machine learning is a part of AI.
It helps systems learn from data.
"""
}
for filepath, content in sample_texts.items():
    with open(filepath, "w", encoding="utf-8") as f:
        f.write(content)

print("✅ Files created successfully")
# Out:
# ✅ Files created successfully

# %%
from langchain_community.document_loaders import TextLoader

loader = TextLoader("../data/text_files/python_intro.txt", encoding="utf-8")

docs = loader.load()

print(docs)
# Out:
# [Document(metadata={'source': '../data/text_files/python_intro.txt'}, page_content='Python Programming Introduction\n\nPython is a high-level programming language.\nIt is easy to learn and widely used.\n')]

# %%
from langchain_community.document_loaders import DirectoryLoader, TextLoader

dir_loader = DirectoryLoader(
    "../data/text_files",
    glob="**/*.txt",
    loader_cls=TextLoader,
    loader_kwargs={"encoding": "utf-8"},
    show_progress=True
)

documents = dir_loader.load()

print(documents)
# Out:
# To log the progress of DirectoryLoader you need to install tqdm, `pip install tqdm`
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\Users\Dell\OneDrive\Desktop\YTRAG\.venv\Lib\site-packages\langchain_community\document_loaders\directory.py:159, in DirectoryLoader.lazy_load(self)
#     158 try:
# --> 159     from tqdm import tqdm
#     161     pbar = tqdm(total=len(items))
#
# ModuleNotFoundError: No module named 'tqdm'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[6], line 11
#       7     loader_kwargs={"encoding": "utf-8"},
#       8     show_progress=True
#       9 )
#      10
# ---> 11 documents = dir_loader.load()
#      12
#      13 print(documents)
#
# File c:\Users\Dell\OneDrive\Desktop\YTRAG\.venv\Lib\site-packages\langchain_community\document_loaders\directory.py:117, in DirectoryLoader.load(self)
#     115 def load(self) -> List[Document]:
#     116     """Load documents."""
# --> 117     return list(self.lazy_load())
#
# File c:\Users\Dell\OneDrive\Desktop\YTRAG\.venv\Lib\site-packages\langchain_community\document_loaders\directory.py:170, in DirectoryLoader.lazy_load(self)
#     168             logger.warning(e)
#     169         else:
# --> 170             raise ImportError(
#     171                 "To log the progress of DirectoryLoader "
#     172                 "you need to install tqdm, "
#     173                 "`pip install tqdm`"
#     174             )
#     176 if self.use_multithreading:
#     177     futures = []
#
# ImportError: To log the progress of DirectoryLoader you need to install tqdm, `pip install tqdm`
