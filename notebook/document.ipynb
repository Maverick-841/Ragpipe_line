# %% [markdown]
# from langchain_core.documents import Document as DOC

# %%
from langchain_core.documents import Document as DOC

doc = DOC(
    page_content="Hello",
    metadata={"source": "test"}
)
print(doc)
# Out:
# page_content='Hello' metadata={'source': 'test'}

# %%
import os 
os.makedirs("../data/text_files", exist_ok=True)

# %%
sample_texts = {
    "../data/text_files/python_intro.txt": """Python Programming Introduction

Python is a high-level programming language.
It is easy to learn and widely used.
""",

    "../data/text_files/ml_intro.txt": """Machine Learning Basics

Machine learning is a part of AI.
It helps systems learn from data.
"""
}
for filepath, content in sample_texts.items():
    with open(filepath, "w", encoding="utf-8") as f:
        f.write(content)

print("✅ Files created successfully")
# Out:
# ✅ Files created successfully

# %%
from langchain_community.document_loaders import TextLoader

loader = TextLoader("../data/text_files/python_intro.txt", encoding="utf-8")

docs = loader.load()

print(docs)
# Out:
# [Document(metadata={'source': '../data/text_files/python_intro.txt'}, page_content='Python Programming Introduction\n\nPython is a high-level programming language.\nIt is easy to learn and widely used.\n')]

# %%
from langchain_community.document_loaders import DirectoryLoader, TextLoader

dir_loader = DirectoryLoader(
    "../data/text_files",
    glob="**/*.txt",
    loader_cls=TextLoader,
    loader_kwargs={"encoding": "utf-8"},
    show_progress=True
)

documents = dir_loader.load()

print(documents)
# Out:
# c:\Users\Dell\OneDrive\Desktop\YTRAG\.venv\Lib\site-packages\langchain_core\_api\deprecation.py:25: UserWarning: Core Pydantic V1 functionality isn't compatible with Python 3.14 or greater.
#   from pydantic.v1.fields import FieldInfo as FieldInfoV1
# 100%|██████████| 2/2 [00:00<00:00, 62.16it/s]
# [Document(metadata={'source': '..\\data\\text_files\\ml_intro.txt'}, page_content='Machine Learning Basics\n\nMachine learning is a part of AI.\nIt helps systems learn from data.\n'), Document(metadata={'source': '..\\data\\text_files\\python_intro.txt'}, page_content='Python Programming Introduction\n\nPython is a high-level programming language.\nIt is easy to learn and widely used.\n')]
